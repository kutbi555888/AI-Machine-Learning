# %% [markdown]
# # Training

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('tuberculosis_xray_dataset 4.csv')

# %%
df.head()
# Out:
#   Patient_ID Age  Gender Chest_Pain  Cough_Severity  Breathlessness Fatigue  \
# 0  PID000001  69    Male        Yes             1.0             2.0       3
# 1  PID000002  32  Female        Yes             3.0             0.0       9
# 2  PID000003  89    Male         No             7.0             0.0       3
# 3  PID000004  78  Female        Yes             2.0             0.0       6
# 4  PID000005  38    Male         No             7.0             2.0       5
#
#   Weight_Loss     Fever Night_Sweats Sputum_Production Blood_in_Sputum  \
# 0        2.37  Moderate          Yes            Medium             Yes
# 1        6.09  Moderate           No            Medium              No
# 2        2.86      Mild          Yes            Medium              No
# 3        4.57  Moderate           No              High             Yes
# 4       13.86      High          Yes               Low              No
#
#   Smoking_History Previous_TB_History         Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19986 entries, 0 to 19985
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           19986 non-null  object
#  1   Age                  19986 non-null  object
#  2   Gender               19985 non-null  object
#  3   Chest_Pain           19986 non-null  object
#  4   Cough_Severity       19985 non-null  float64
#  5   Breathlessness       19986 non-null  float64
#  6   Fatigue              19986 non-null  object
#  7   Weight_Loss          19986 non-null  object
#  8   Fever                19986 non-null  object
#  9   Night_Sweats         19986 non-null  object
#  10  Sputum_Production    19986 non-null  object
#  11  Blood_in_Sputum      19986 non-null  object
#  12  Smoking_History      19985 non-null  object
#  13  Previous_TB_History  19985 non-null  object
#  14  Class                19884 non-null  object
# ...

# %%
from datacleaner import autoclean

# %%
df=autoclean(df)
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datacleaner\datacleaner.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19986 entries, 0 to 19985
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           19986 non-null  int64
#  1   Age                  19986 non-null  int64
#  2   Gender               19986 non-null  int64
#  3   Chest_Pain           19986 non-null  int64
#  4   Cough_Severity       19986 non-null  float64
#  5   Breathlessness       19986 non-null  float64
#  6   Fatigue              19986 non-null  int64
#  7   Weight_Loss          19986 non-null  int64
#  8   Fever                19986 non-null  int64
#  9   Night_Sweats         19986 non-null  int64
#  10  Sputum_Production    19986 non-null  int64
#  11  Blood_in_Sputum      19986 non-null  int64
#  12  Smoking_History      19986 non-null  int64
#  13  Previous_TB_History  19986 non-null  int64
#  14  Class                19986 non-null  int64
# ...

# %%
df['Class']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 19981    0
# 19982    1
# 19983    0
# 19984    0
# 19985    0
# Name: Class, Length: 19986, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    14096
# 1     5890
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19986 entries, 0 to 19985
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           19986 non-null  int64
#  1   Age                  19986 non-null  int64
#  2   Gender               19986 non-null  int64
#  3   Chest_Pain           19986 non-null  int64
#  4   Cough_Severity       19986 non-null  float64
#  5   Breathlessness       19986 non-null  float64
#  6   Fatigue              19986 non-null  int64
#  7   Weight_Loss          19986 non-null  int64
#  8   Fever                19986 non-null  int64
#  9   Night_Sweats         19986 non-null  int64
#  10  Sputum_Production    19986 non-null  int64
#  11  Blood_in_Sputum      19986 non-null  int64
#  12  Smoking_History      19986 non-null  int64
#  13  Previous_TB_History  19986 non-null  int64
#  14  Class                19986 non-null  int64
# ...

# %%
x=df.drop('Class',axis=1)

# %%
y=df['Class']

# %%
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
x_train.shape
# Out:
# (15988, 14)

# %%
y_train.shape
# Out:
# (15988,)

# %%
x_val.shape
# Out:
# (1999, 14)

# %%
x_test.shape
# Out:
# (1999, 14)

# %%
x_train
# Out:
#        Patient_ID  Age  Gender  Chest_Pain  Cough_Severity  Breathlessness  \
# 10666       10664    3       1          10             5.0             2.0
# 841           839   32       1          10             3.0             1.0
# 5584         5582   54       1          11             0.0             0.0
# 7760         7758   31       1          11             1.0             0.0
# 11934       11932   29       2          10             3.0             2.0
# ...           ...  ...     ...         ...             ...             ...
# 11284       11282    7       1          10             1.0             3.0
# 11964       11962   38       1          11             7.0             1.0
# 5390         5388   71       1          10             4.0             1.0
# 860           858   14       1          10             7.0             2.0
# 15795       15793   67       2          10             0.0             3.0
#
# ...

# %%
x_val
# Out:
#        Patient_ID  Age  Gender  Chest_Pain  Cough_Severity  Breathlessness  \
# 17221       17219   61       2          11             1.0             2.0
# 8596         8594   55       2          11             7.0             0.0
# 15135       15133   16       1          10             7.0             0.0
# 8836         8834    3       2          10             4.0             1.0
# 8132         8130   22       1          10             0.0             1.0
# ...           ...  ...     ...         ...             ...             ...
# 9029         9027   34       1          11             4.0             2.0
# 2041         2039   19       1          11             8.0             3.0
# 13115       13113   15       2          10             4.0             1.0
# 14266       14264   42       1          10             1.0             1.0
# 1006         1004   54       2          11             0.0             4.0
#
# ...

# %%
x_test
# Out:
#        Patient_ID  Age  Gender  Chest_Pain  Cough_Severity  Breathlessness  \
# 15055       15053   37       1          11             2.0             3.0
# 11480       11478    7       2          11             4.0             1.0
# 13961       13959   20       2          10             1.0             2.0
# 15420       15418   18       1          10             2.0             2.0
# 11176       11174   30       1          10             1.0             4.0
# ...           ...  ...     ...         ...             ...             ...
# 11212       11210   65       1          11             5.0             4.0
# 4072         4070   15       2          10             3.0             1.0
# 18714       18712   59       1          11             4.0             1.0
# 16062       16060   27       1          10             8.0             0.0
# 9246         9244   62       1          11             4.0             1.0
#
# ...

# %%
log_model=LogisticRegression(random_state=42)

# %%
log_model
# Out:
# LogisticRegression(random_state=42)

# %%
log_model.fit(x_train,y_train)
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
log_pred=log_model.predict(x_val)

# %%
log_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(1999,))

# %%
log_score=accuracy_score(y_val,log_pred)

# %%
print('LogisticRegression score:',log_score)
# Out:
# LogisticRegression score: 0.7028514257128564

# %%
log_pred_test=log_model.predict(x_test)

# %%
log_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(1999,))

# %%
log_score_test=accuracy_score(y_test,log_pred_test)

# %%
log_score_test
# Out:
# 0.6923461730865432

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
kf=KFold(n_splits=5,shuffle=True,random_state=42)

# %%
kf
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
k_score=cross_val_score(log_model,x,y,cv=kf)
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
k_score
# Out:
# array([0.6975988 , 0.72129097, 0.69251939, 0.69877408, 0.71628722])

# %%
k_score.std()
# Out:
# np.float64(0.011328458956098632)

# %%
k_score.mean()
# Out:
# np.float64(0.7052940906280011)

# %%
k_score.max()
# Out:
# np.float64(0.7212909682261697)

# %% [markdown]
# # Training Process

# %%
import pandas as pd

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from datacleaner import autoclean
df=autoclean(df)
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datacleaner\datacleaner.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int64
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    int64
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 83.7 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression

# %%
x=df.drop('Embarked',axis=1)
y=df['Embarked']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int64
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    int64
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 83.7 KB

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   108    1  22.0      1      0     523
# 1            2         1       1   190    0  38.0      1      0     596
# 2            3         1       3   353    0  26.0      0      0     669
# 3            4         1       1   272    0  35.0      1      0      49
# 4            5         0       3    15    1  35.0      0      0     472
# 5            6         0       3   554    1  28.0      0      0     275
# 6            7         0       1   515    1  54.0      0      0      85
# 7            8         0       3   624    1   2.0      3      1     395
#
#       Fare  Cabin  Embarked
# 0   7.2500     47         2
# 1  71.2833     81         0
# 2   7.9250     47         2
# 3  53.1000     55         2
# 4   8.0500     47         2
# 5   8.4583     47         1
# 6  51.8625    129         2
# 7  21.0750     47         2

# %%
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2,random_state=42)
x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
lr_model=LogisticRegression(random_state=42)

# %%
lr_model.fit(x_train,y_train)
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_val_pred=lr_model.predict(x_val)
accuracy_score_val=lr_model.score(x_val,y_val)
accuracy_score_val
# Out:
# 0.7333333333333333

# %%
lr_model = LogisticRegression()
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
kf
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
scores = cross_val_score(lr_model, x, y, cv=kf, scoring='accuracy')
# Out:
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
print(f'Cross-Validation Accuracy Scores: {scores}')
print(f'Mean Accuracy: {scores.mean():.2f}')
print(f'Standard Deviation: {scores.std():.2f}')
# Out:
# Cross-Validation Accuracy Scores: [0.67597765 0.7752809  0.64606742 0.7752809  0.74157303]
# Mean Accuracy: 0.72
# Standard Deviation: 0.05

# %%
y_test_pred=lr_model.predict(x_test)
accuracy_score_test=lr_model.score(x_test,y_test)
accuracy_score_test
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 y_test_pred=lr_model.predict(x_test)
#       2 accuracy_score_test=lr_model.score(x_test,y_test)
#       3 accuracy_score_test
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)
#     371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# ...

# %%
y_pred=lr_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 y_pred=lr_model.predict(x_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)
#     371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# ...

# %%
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 y_pred
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import accuracy_score

# %%
y_final=accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 y_final=accuracy_score(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
y_final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 y_final
#
# NameError: name 'y_final' is not defined

# %%
y_val_pred=lr_model.predict(x_val)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 y_val_pred=lr_model.predict(x_val)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)
#     371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# ...

# %%
accuracy_score(y_val,y_val_pred)
# Out:
# 0.7333333333333333
