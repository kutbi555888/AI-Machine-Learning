# %% [markdown]
# # Pycaret Regression

# %%
# !pip install pycaret
import pandas as pd
df=pd.read_csv('global_cancer_patients_2015_2024(in)Classification.csv')
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\xolmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49980 entries, 0 to 49979
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             49888 non-null  object
#  1   Age                    49908 non-null  float64
#  2   Gender                 49908 non-null  object
#  3   Country_Region         49907 non-null  object
#  4   Year                   49908 non-null  float64
#  5   Genetic_Risk           49908 non-null  float64
#  6   Air_Pollution          49908 non-null  float64
#  7   Alcohol_Use            49908 non-null  float64
#  8   Smoking                49891 non-null  float64
#  9   Obesity_Level          49908 non-null  float64
#  10  Cancer_Stage           49908 non-null  object
#  11  Treatment_Cost_USD     49908 non-null  float64
#  12  Survival_Years         49908 non-null  float64
#  13  Target_Severity_Score  49908 non-null  float64
# ...

# %%
# Pycaretni import qilish     Classification yoki Regression yoki Clustering     (classlar,funksiyalar,kutubxonalar)
from pycaret.regression import *

# %%
# Setup qilish
# bu cod training jarayonigacha qilib beradi
s=setup(df,target='Target_Severity_Score',session_id=123)       # Target_Severity_Score da missing value bor deyapti
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Setup qilish
#       2 # bu cod training jarayonigacha qilib beradi
# ----> 3 s=setup(df,target='Target_Severity_Score',session_id=123)       # Target_Severity_Score da missing value bor deyapti
#
# ...

# %%
df['Target_Severity_Score'].fillna(df['Target_Severity_Score'].mean(), inplace=True)

# %%
df['Target_Severity_Score'].isnull().sum()
# Out:
# 0

# %%
# Funksional yol(qisqaroq datasetlar uchun,tezroq natija olish uchun ishlatiladi)
s=setup(df,target='Target_Severity_Score',session_id=123)          # session_id randomli ishlaydi
# Out:
# <style type="text/css">
# #T_f1322_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1322">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1322_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f1322_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1322_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1322_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f1322_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f1322_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1322_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f1322_row1_col1" class="data row1 col1" >Target_Severity_Score</td>
#     </tr>
#     <tr>
#       <th id="T_f1322_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Setup 2  (OOB - Object Oriented Way)  Katta datasetlarda ishlatiladi
from pycaret.regression import RegressionExperiment      # bu cod training jarayonigacha qilib beradi
s=RegressionExperiment()
s.setup(df,target='Target_Severity_Score',session_id=123)
# Out:
# <style type="text/css">
# #T_53588_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_53588">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53588_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_53588_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53588_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53588_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_53588_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_53588_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53588_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_53588_row1_col1" class="data row1 col1" >Target_Severity_Score</td>
#     </tr>
#     <tr>
#       <th id="T_53588_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Modelni Training qilish    'Funksional yol'
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_7827a th {
#   text-align: left;
# }
# ...

# %%
# Modelni Training qilish    'OOB - Object Oriented Way'
best_model=s.compare_models()
# Out:
# <style type="text/css">
# #T_98c8e th {
#   text-align: left;
# }
# ...

# %%
# Hamma modellarni bitta visualisatonga jamlash
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# OOB (Object Oriented Wayni Visualisationi)
s.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Modelni funksional yol bilan qilinganini pkl qilib saqlsh
save_model(best_model,'Eng yaxshi model regression1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Age', 'Year', 'Genetic_Risk',
#                                               'Air_Pollution', 'Alcohol_Use',
#                                               'Smoking', 'Obesity_Level',
#                                               'Treatment_Cost_USD',
#                                               'Survival_Years'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Patient_ID', 'Gender',
#                                               'Country_Region', 'Cancer_Stage...
#                   TransformerWrapper(include=['Gender', 'Country_Region',
#                                               'Cancer_Stage'],
#                                      transformer=OneHotEncoder(cols=['Gender',
# ...

# %%
# Modelni OOB - Object Oriented Way yoli bilan qilinganini pkl qilib saqlsh
s.save_model(best_model,'Eng yaxshi model regression2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Age', 'Year', 'Genetic_Risk',
#                                               'Air_Pollution', 'Alcohol_Use',
#                                               'Smoking', 'Obesity_Level',
#                                               'Treatment_Cost_USD',
#                                               'Survival_Years'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Patient_ID', 'Gender',
#                                               'Country_Region', 'Cancer_Stage...
#                   TransformerWrapper(include=['Gender', 'Country_Region',
#                                               'Cancer_Stage'],
#                                      transformer=OneHotEncoder(cols=['Gender',
# ...

# %%
# Modelni Load qilish(Funksional yol bilan qilinganini)
load_model=load_model('Eng yaxshi model regression1')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Modelni Load qilish(OOB - Object Oriented Way yoli bilan qilinganini)
load_model2=s.load_model('Eng yaxshi model regression2')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# # Pycaret Classification

# %%
# !pip install pycaret
import pandas as pd
df=pd.read_csv('Titanic-DatasetClassification.csv')
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\xolmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Pycaretni import qilish     Classification yoki Regression yoki Clustering     (classlar,funksiyalar,kutubxonalar)
from pycaret.classification import *

# %%
# Setup qilish
# bu cod training jarayonigacha qilib beradi
# Funksional yol(qisqaroq datasetlar uchun,tezroq natija olish uchun ishlatiladi)
# session_id randomli ishlaydi
s=setup(df,target='Survived',session_id=123)
# Out:
# <style type="text/css">
# #T_014df_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_014df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_014df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_014df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_014df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_014df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_014df_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_014df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_014df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_014df_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_014df_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Setup 2  (OOB - Object Oriented Way)  Katta datasetlarda ishlatiladi
from pycaret.classification import ClassificationExperiment     # bu cod training jarayonigacha qilib beradi
s=ClassificationExperiment()
s.setup(df,target='Survived',session_id=123)
# Out:
# <style type="text/css">
# #T_05d6e_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_05d6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05d6e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_05d6e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05d6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05d6e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_05d6e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_05d6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05d6e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_05d6e_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_05d6e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Modelni Training qilish    'Funksional yol'
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_d08bd th {
#   text-align: left;
# }
# ...

# %%
# Modelni Training qilish    'OOB - Object Oriented Way'
best_model=s.compare_models()
# Out:
# <style type="text/css">
# #T_85df1 th {
#   text-align: left;
# }
# ...

# %%
# Hamma modellarni bitta visualisatonga jamlash
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# OOB (Object Oriented Wayni Visualisationi)
s.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Modelni funksional yol bilan qilinganini pkl qilib saqalsh
save_model(best_model,'Eng yaxshi model classification1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['PassengerId', 'Pclass', 'Age',
#                                               'SibSp', 'Parch', 'Fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None...
# ...

# %%
# Modelni OOB - Object Oriented Way yoli bilan qilinganini pkl qilib saqlsh
s.save_model(best_model,'Eng yaxshi model classification2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['PassengerId', 'Pclass', 'Age',
#                                               'SibSp', 'Parch', 'Fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None...
# ...

# %%
# Modelni Load qilish(Funksional yol bilan qilinganini)
load_model=load_model('Eng yaxshi model regression1')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Modelni Load qilish(OOB - Object Oriented Way yoli bilan qilinganini)
load_model2=s.load_model('Eng yaxshi model regression2')
# Out:
# Transformation Pipeline and Model Successfully Loaded
