# %% [markdown]
# # Linear model va Decision Tre

# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('telefon turini aniqlash2.csv')

# %%
df.head()
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi      Rangi  Vazni  ...  \
# 0            1   0             7               0.6      Qizil    188  ...
# 1            0   1            53               0.7     Yashil    136  ...
# 2            2   1            41               0.9      Sariq    145  ...
# 3            0   0            10               0.8  Jigarrang    131  ...
# 4           13   1            44               0.6         Oq    141  ...
#
#    Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# 0                        756.0  2549                9.0
# 1                       1988.0  2631               17.0
# 2                       1716.0  2603               11.0
# 3                       1786.0  2769               16.0
# 4                       1212.0  1411                8.0
#
#    Qurilma ekran kengligi(cm)  Bir_quvvatlashdagi gaplashish  3g  \
# 0                         7.0                             19   0
# 1                         3.0                              7   1
# 2                         2.0                              9   1
# 3                         8.0                             11   1
# 4                         2.0                             15   1
#
#    Qurilma xajmi(pix).1  sensorli  wifi  telefon_turi
# 0                  20.0         0     1             1
# 1                 905.0         1     0             2
# 2                1263.0         1     0             2
# 3                1216.0         0     0             2
# 4                1208.0         1     0             1
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          2001 non-null   object
#  9   Vazni                          2001 non-null   int64
#  10  Protsessor yadrolari soni      2000 non-null   float64
#  11  Asosiy kamera                  1999 non-null   float64
#  12  Qurilma xajmi(pix)             1999 non-null   float64
#  13  Qurilma ekran kengligi(pix)    1998 non-null   float64
#  14  ram                            2001 non-null   int64
#  15  Qurilma xajmi(cm)              2000 non-null   float64
#  16  Qurilma ekran kengligi(cm)     2000 non-null   float64
#  17  Bir_quvvatlashdagi gaplashish  2001 non-null   int64
#  18  3g                             2001 non-null   int64
#  19  Qurilma xajmi(pix).1           1999 non-null   float64
#  20  sensorli                       2001 non-null   int64
#  21  wifi                           2001 non-null   int64
#  22  telefon_turi                   2001 non-null   int64
# dtypes: float64(9), int64(13), object(1)
# memory usage: 359.7+ KB

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 3
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
tushib_qolganlar=df.columns[df.isnull().any()]

# %%
tushib_qolganlar
# Out:
# Index(['tel_ingichgaligi', 'Protsessor yadrolari soni', 'Asosiy kamera',
#        'Qurilma xajmi(pix)', 'Qurilma ekran kengligi(pix)',
#        'Qurilma xajmi(cm)', 'Qurilma ekran kengligi(cm)',
#        'Qurilma xajmi(pix).1'],
#       dtype='object')

# %%
df=df.dropna(subset=tushib_qolganlar)

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    0
# Qurilma xajmi(pix)               0
# Qurilma ekran kengligi(pix)      0
# ram                              0
# Qurilma xajmi(cm)                0
# Qurilma ekran kengligi(cm)       0
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             0
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1988 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1988 non-null   int64
#  1   blutus                         1988 non-null   int64
#  2   protsessor_tezligi             1988 non-null   float64
#  3   ikkita simkartalik             1988 non-null   int64
#  4   Oldi_kamera                    1988 non-null   int64
#  5   4G                             1988 non-null   int64
#  6   Ichki_xotira                   1988 non-null   int64
#  7   tel_ingichgaligi               1988 non-null   float64
#  8   Rangi                          1988 non-null   object
#  9   Vazni                          1988 non-null   int64
#  10  Protsessor yadrolari soni      1988 non-null   float64
#  11  Asosiy kamera                  1988 non-null   float64
#  12  Qurilma xajmi(pix)             1988 non-null   float64
#  13  Qurilma ekran kengligi(pix)    1988 non-null   float64
#  14  ram                            1988 non-null   int64
#  15  Qurilma xajmi(cm)              1988 non-null   float64
#  16  Qurilma ekran kengligi(cm)     1988 non-null   float64
#  17  Bir_quvvatlashdagi gaplashish  1988 non-null   int64
#  18  3g                             1988 non-null   int64
#  19  Qurilma xajmi(pix).1           1988 non-null   float64
#  20  sensorli                       1988 non-null   int64
#  21  wifi                           1988 non-null   int64
#  22  telefon_turi                   1988 non-null   int64
# dtypes: float64(9), int64(13), object(1)
# memory usage: 372.8+ KB

# %%
# encoding

# %%
df['Rangi'].value_counts().sum()
# Out:
# np.int64(1988)

# %%
df['Rangi'].value_counts()
# Out:
# Rangi
# Qora         1977
# Yashil          7
# Qizil           1
# Sariq           1
# Jigarrang       1
# Oq              1
# Name: count, dtype: int64

# %%
cardinality=df.nunique()

# %%
cardinality
# Out:
# battereya_hajmi                  1089
# blutus                              2
# protsessor_tezligi                 26
# ikkita simkartalik                  2
# Oldi_kamera                        20
# 4G                                  2
# Ichki_xotira                       63
# tel_ingichgaligi                   10
# Rangi                               6
# Vazni                             121
# Protsessor yadrolari soni           8
# Asosiy kamera                      21
# Qurilma xajmi(pix)               1134
# Qurilma ekran kengligi(pix)      1104
# ram                              1554
# Qurilma xajmi(cm)                  15
# Qurilma ekran kengligi(cm)         19
# Bir_quvvatlashdagi gaplashish      19
# 3g                                  2
# Qurilma xajmi(pix).1             1134
# sensorli                            2
# wifi                                2
# telefon_turi                        4
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype=='object':
        if cardinality[col]<=5:
            df=pd.get_dummies(df,columns=[col],dtype=int,drop_first=True)
        else:
            le=LabelEncoder()
            df[col]=le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1988 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1988 non-null   int64
#  1   blutus                         1988 non-null   int64
#  2   protsessor_tezligi             1988 non-null   float64
#  3   ikkita simkartalik             1988 non-null   int64
#  4   Oldi_kamera                    1988 non-null   int64
#  5   4G                             1988 non-null   int64
#  6   Ichki_xotira                   1988 non-null   int64
#  7   tel_ingichgaligi               1988 non-null   float64
#  8   Rangi                          1988 non-null   int64
#  9   Vazni                          1988 non-null   int64
#  10  Protsessor yadrolari soni      1988 non-null   float64
#  11  Asosiy kamera                  1988 non-null   float64
#  12  Qurilma xajmi(pix)             1988 non-null   float64
#  13  Qurilma ekran kengligi(pix)    1988 non-null   float64
#  14  ram                            1988 non-null   int64
#  15  Qurilma xajmi(cm)              1988 non-null   float64
#  16  Qurilma ekran kengligi(cm)     1988 non-null   float64
#  17  Bir_quvvatlashdagi gaplashish  1988 non-null   int64
#  18  3g                             1988 non-null   int64
#  19  Qurilma xajmi(pix).1           1988 non-null   float64
#  20  sensorli                       1988 non-null   int64
#  21  wifi                           1988 non-null   int64
#  22  telefon_turi                   1988 non-null   int64
# dtypes: float64(9), int64(14)
# memory usage: 372.8 KB

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns

# %%
num_col
# Out:
# Index(['battereya_hajmi', 'blutus', 'protsessor_tezligi', 'ikkita simkartalik',
#        'Oldi_kamera', '4G', 'Ichki_xotira', 'tel_ingichgaligi', 'Rangi',
#        'Vazni', 'Protsessor yadrolari soni', 'Asosiy kamera',
#        'Qurilma xajmi(pix)', 'Qurilma ekran kengligi(pix)', 'ram',
#        'Qurilma xajmi(cm)', 'Qurilma ekran kengligi(cm)',
#        'Bir_quvvatlashdagi gaplashish', '3g', 'Qurilma xajmi(pix).1',
#        'sensorli', 'wifi', 'telefon_turi'],
#       dtype='object')

# %%
scaler=StandardScaler()

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#    battereya_hajmi    blutus  protsessor_tezligi  ikkita simkartalik  \
# 0        -0.905428 -0.987006            0.831043           -1.022383
# 1        -0.497737  1.013165           -1.250476            0.978107
# 2        -1.540879  1.013165           -1.250476            0.978107
# 3        -1.422444  1.013165            1.198370           -1.022383
# 4         1.324344  1.013165           -0.393380           -1.022383
#
#    Oldi_kamera        4G  Ichki_xotira  tel_ingichgaligi      Rangi     Vazni  \
# 0    -0.763346 -1.041085     -1.382759          0.341750  -6.833473  1.346430
# 1    -0.993309  0.960537      1.152743          0.688559  13.574556 -0.120798
# 2    -0.533382  0.960537      0.491308          1.382177   6.771880  0.133146
# 3    -0.993309 -1.041085     -1.217400          1.035368 -20.438826 -0.261877
# 4     1.996220  0.960537      0.656666          0.341750 -13.636150  0.020282
#
#    ...  Qurilma ekran kengligi(pix)       ram  Qurilma xajmi(cm)  \
# 0  ...                    -1.144596  0.393106          -0.783630
# 1  ...                     1.705109  0.468699           1.114170
# 2  ...                     1.075953  0.442887          -0.309180
# 3  ...                     1.237868  0.595917           0.876945
# 4  ...                    -0.089835 -0.655977          -1.020855
#
#    Qurilma ekran kengligi(cm)  Bir_quvvatlashdagi gaplashish        3g  \
# 0                    0.285307                       1.458776 -1.782266
# 1                   -0.634336                      -0.737120  0.561084
# 2                   -0.864246                      -0.371137  0.561084
# 3                    0.515217                      -0.005155  0.561084
# 4                   -0.864246                       0.726811  0.561084
#
#    Qurilma xajmi(pix).1  sensorli      wifi  telefon_turi
# 0             -1.406846 -1.004032  0.983041     -0.445415
# 1              0.586068  0.995984 -1.017251      0.449014
# 2              1.392241  0.995984 -1.017251      0.449014
# 3              1.286402 -1.004032 -1.017251      0.449014
# 4              1.268387  0.995984 -1.017251     -0.445415
#
# [5 rows x 23 columns]

# %%
x=df.drop(columns=['telefon_turi'])

# %%
x.head()
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Rangi  Vazni  ...  \
# 0            1   0             7               0.6      2    188  ...
# 1            0   1            53               0.7      5    136  ...
# 2            2   1            41               0.9      4    145  ...
# 3            0   0            10               0.8      0    131  ...
# 4           13   1            44               0.6      1    141  ...
#
#    Qurilma xajmi(pix)  Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# 0                20.0                        756.0  2549                9.0
# 1               905.0                       1988.0  2631               17.0
# 2              1263.0                       1716.0  2603               11.0
# 3              1216.0                       1786.0  2769               16.0
# 4              1208.0                       1212.0  1411                8.0
#
#    Qurilma ekran kengligi(cm)  Bir_quvvatlashdagi gaplashish  3g  \
# 0                         7.0                             19   0
# 1                         3.0                              7   1
# 2                         2.0                              9   1
# 3                         8.0                             11   1
# 4                         2.0                             15   1
#
#    Qurilma xajmi(pix).1  sensorli  wifi
# 0                  20.0         0     1
# 1                 905.0         1     0
# 2                1263.0         1     0
# 3                1216.0         0     0
# 4                1208.0         1     0
#
# [5 rows x 22 columns]

# %%
y=df['telefon_turi']

# %%
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2,random_state=42)
x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
x_train.shape
# Out:
# (1590, 22)

# %%
y_train.shape
# Out:
# (1590,)

# %%
x_test.shape
# Out:
# (199, 22)

# %%
y_test.shape
# Out:
# (199,)

# %%
x_val.shape
# Out:
# (199, 22)

# %%
y_val.shape
# Out:
# (199,)

# %%
#Model Selection
model=LinearRegression()

# %%
linear_model=model.fit(x_train,y_train)

# %%
linear_model
# Out:
# LinearRegression()

# %%
y_pred=linear_model.predict(x_test)

# %%
y_pred
# Out:
# array([ 0.46322022,  2.52643318,  1.98324727, -0.40212806,  1.80485616,
#         2.5163283 ,  1.77069409,  2.44964992,  0.55509031,  0.4901008 ,
#         0.69569121,  2.13760823,  1.93330411,  1.56438242,  1.96627929,
#        -0.03096221,  1.51754051,  1.20794507,  2.85153669,  3.03693534,
#         0.78087936, -0.10125239,  1.75769953,  1.9837439 ,  1.72392113,
#         1.15792717,  1.92836306,  1.19127007,  2.89029573, -0.35229123,
#         2.0587336 ,  1.03406089,  0.25215304,  1.29836771, -0.10446252,
#         2.68605599,  0.49982569,  2.47880964,  2.87822287,  0.1312374 ,
#        -0.66556889, -0.61611138,  1.40949396,  1.35005425,  0.63302498,
#         0.43312143, -0.01247896,  0.43137976,  3.27673727,  3.25883454,
#        -0.37219408,  0.6734087 ,  3.31122846,  2.33976069,  0.27580756,
#         2.99777629,  1.37831921,  1.25981627,  1.27424856,  1.83577791,
#         1.31365957,  0.89829274,  0.25443994,  1.27763916,  2.44838552,
#         1.20532838, -0.09081153,  0.41337945,  1.10458467,  3.31968646,
#         1.12970867,  1.37131338,  1.29527327,  0.94843576,  0.49246379,
#         0.25930331,  3.31409538,  3.09691931, -0.04138726,  3.37607981,
#         1.55735282,  2.67356305,  3.58891148,  1.82192407,  2.83884324,
#         0.54563336,  0.32574161,  3.47047145,  0.3648062 ,  3.30165992,
#         0.24043344,  0.5706494 ,  1.54416066,  2.93826887,  0.88778974,
#         2.32296402, -0.5332983 ,  1.88625507,  3.23819942,  1.94523314,
#         3.28007092,  1.88468401,  3.47042948,  0.90677364,  1.91846813,
#        -0.02410072,  1.71897235,  1.90186235,  0.022688  ,  0.04922761,
#         1.67119471,  2.6087158 ,  2.56818434,  2.23313347,  1.36172266,
#         1.18646393,  1.8488401 ,  2.89400721,  3.14406197,  1.66222824,
#        -0.45165085,  2.4929255 , -0.00550952,  0.55771089,  1.61090549,
#         1.07907645,  3.47677634,  1.30006448,  0.55351884,  2.17821628,
#         1.39823538,  0.13219495,  1.11055187,  0.92086981,  0.20843222,
#         0.67112197,  0.95416693,  3.01214242,  0.73263873,  3.21629309,
#         3.21139405,  0.96786647,  1.29460407, -0.03553043,  0.39683859,
#         1.33376281,  1.56731016,  0.21600394, -0.06422328,  1.98410783,
#        -0.1585659 ,  0.51142369,  1.25477479,  2.9237243 , -0.75814759,
#         3.39740423,  0.45606664,  1.81463155,  0.42515694,  2.77286709,
#         1.28188733, -0.24353928,  3.03031143,  0.07500051,  3.45258179,
#         2.47237813, -0.05398775,  3.36421569,  1.23757222, -0.38842034,
#         0.1506462 ,  2.14768994,  0.87047287,  0.80641395,  3.60805178,
#         3.36003215,  1.44831947,  2.81379167,  0.68635816,  2.07950324,
#         1.56286853,  0.71061361,  3.14953428,  0.07355522,  1.23833131,
#         0.23968572,  0.44134009,  1.87170167,  1.08749902,  1.08244459,
#         2.61505839,  2.89787797,  3.81325011,  1.84520766,  1.84593879,
#         0.37291629, -0.14374216,  0.00871516,  2.27286909])

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1996    0
# 1997    2
# 1998    3
# 1999    0
# 2000    3
# Name: telefon_turi, Length: 1988, dtype: int64

# %%
mse_linear=mean_squared_error(y_test,y_pred)
r2_linear=r2_score(y_test,y_pred)

# %%
print(mse_linear)
print(r2_linear)
# Out:
# 0.105094808561666
# 0.9220742301930323

# %%
# Decision Tree

# %%
model=DecisionTreeRegressor()

# %%
model
# Out:
# DecisionTreeRegressor()

# %%
dt_model=model.fit(x_train,y_train)

# %%
dt_model
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt_model.predict(x_test)

# %%
y_pred
# Out:
# array([1., 3., 2., 0., 2., 3., 2., 3., 1., 1., 1., 2., 3., 2., 2., 0., 1.,
#        1., 3., 3., 0., 0., 2., 2., 2., 1., 2., 1., 3., 0., 2., 0., 0., 1.,
#        0., 3., 0., 2., 3., 0., 0., 0., 1., 1., 1., 0., 0., 1., 3., 3., 0.,
#        0., 3., 2., 0., 3., 1., 1., 1., 2., 1., 0., 0., 1., 3., 1., 0., 0.,
#        1., 3., 1., 2., 1., 1., 1., 0., 3., 3., 0., 3., 2., 3., 3., 1., 3.,
#        0., 0., 3., 0., 3., 0., 1., 2., 3., 1., 2., 0., 2., 3., 1., 3., 2.,
#        3., 1., 2., 0., 2., 1., 0., 0., 2., 2., 2., 2., 1., 1., 2., 3., 3.,
#        3., 0., 3., 0., 1., 1., 1., 3., 1., 0., 2., 1., 0., 1., 1., 0., 1.,
#        1., 3., 1., 3., 3., 1., 1., 0., 0., 2., 1., 0., 0., 2., 0., 0., 2.,
#        3., 0., 3., 0., 2., 1., 3., 1., 0., 3., 0., 3., 3., 0., 3., 1., 0.,
#        0., 2., 0., 1., 3., 3., 1., 3., 1., 2., 2., 1., 3., 0., 1., 0., 0.,
#        2., 1., 1., 3., 3., 3., 2., 2., 0., 0., 0., 2.])

# %%
y[:5]
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: telefon_turi, dtype: int64

# %%
mse_tree=mean_squared_error(y_test,y_pred)
r2_tree=r2_score(y_test,y_pred)

# %%
print(mse_tree)
print(r2_tree)
# Out:
# 0.1507537688442211
# 0.888218993409227

# %%
print(mse_tree)
print(r2_tree)
print(mse_linear)
print(r2_linear)
# Out:
# 0.1507537688442211
# 0.888218993409227
# 0.105094808561666
# 0.9220742301930323
